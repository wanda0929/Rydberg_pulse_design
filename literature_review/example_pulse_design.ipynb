# %%
# Rydberg Pulse Design Example

This notebook demonstrates the basic usage of the RydbergPulseDesign package for designing and optimizing Rydberg atom control pulses.

# %%
using RydbergPulseDesign
using Plots

# Set system parameters
Ω = 1.0  # Rabi frequency
Δ = 0.0  # Detuning
n = 2    # Number of levels

# Create Hamiltonian
H = create_rydberg_hamiltonian(Ω, Δ, n)

# Example will be expanded as implementation progresses
